# %%
from bs4 import BeautifulSoup as soup
from datetime import date, datetime
from urllib.request import Request, urlopen

import pandas as pd
import numpy as np


import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px
import plotly.offline as py
import seaborn as sns
import gc
import warnings
warnings.filterwarnings('ignore')
from pandas_profiling import ProfileReport

# %%
article_read = pd.read_csv('1.csv')

# %%
article_read
# Out:
#                     Country_Name Country_Code     Indicator_Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator_Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54208.0      55434.0      56234.0      56699.0
# ...

# %%
# pip install pycountry-convert

# %%
# today = datetime.now()
# yesterday_str = "%s %d, %d" %(date.today().strftime("%b"), today.day-1, today.year)
# today_str = "%s %d, %d" %(date.today().strftime("%b"), today.day, today.year)
# # yesterday_str today_str
# today_str

# %%
# article_read.Country_Name
article_read.Country_Code
# article_read[['Country_Code']]
# Out:
# 0      ABW
# 1      AFE
# 2      AFG
# 3      AFW
# 4      AGO
#       ...
# 261    XKX
# 262    YEM
# 263    ZAF
# 264    ZMB
# 265    ZWE
# Name: Country_Code, Length: 266, dtype: object

# %%
import pycountry_convert as pc

def country_to_continent(country_name):
    country_alpha2 = pc.country_name_to_country_alpha2(country_name)
    country_continent_code = pc.country_alpha2_to_continent_code(country_alpha2)
    country_continent_name = pc.convert_continent_code_to_continent_name(country_continent_code)
    return country_continent_name

# %%
# for i in range(len(article_read.Country_Code)):
#     article_read.Country_Code[i]
#     i += 1
#     country_name = article_read.Country_Code[i]

# print(country_to_continent(country_name))
#     i += 1
# article_read.Country_Code[i]

# %%
# Example
# country_name = article_read.Country_Code


country_name = article_read.Country_Code[2]

print(country_to_continent(country_name))
# Out:
# Asia

# %%
# for x in article_read.Country_Code:
#     print(country_to_continent(x))

# %%
for code in article_read.Country_Code:
    print(code)
# Out:
# ABW
# AFE
# AFG
# AFW
# AGO
# ALB
# AND
# ARB
# ARE
# ARG
# ARM
# ASM
# ATG
# AUS
# AUT
# AZE
# BDI
# BEL
# BEN
# BFA
# BGD
# BGR
# BHR
# BHS
# BIH
# BLR
# BLZ
# BMU
# BOL
# BRA
# BRB
# BRN
# BTN
# BWA
# CAF
# CAN
# CEB
# CHE
# CHI
# CHL
# CHN
# CIV
# CMR
# COD
# COG
# COL
# COM
# CPV
# CRI
# CSS
# CUB
# CUW
# CYM
# CYP
# CZE
# DEU
# DJI
# DMA
# DNK
# DOM
# DZA
# EAP
# EAR
# EAS
# ECA
# ECS
# ECU
# EGY
# EMU
# ERI
# ESP
# EST
# ETH
# EUU
# FCS
# FIN
# FJI
# FRA
# FRO
# FSM
# GAB
# GBR
# GEO
# GHA
# GIB
# GIN
# GMB
# GNB
# GNQ
# GRC
# GRD
# GRL
# GTM
# GUM
# GUY
# HIC
# HKG
# HND
# HPC
# HRV
# HTI
# HUN
# IBD
# IBT
# IDA
# IDB
# IDN
# IDX
# IMN
# IND
# INX
# IRL
# IRN
# IRQ
# ISL
# ISR
# ITA
# JAM
# JOR
# JPN
# KAZ
# KEN
# KGZ
# KHM
# KIR
# KNA
# KOR
# KWT
# LAC
# LAO
# LBN
# LBR
# LBY
# LCA
# LCN
# LDC
# LIC
# LIE
# LKA
# LMC
# LMY
# LSO
# LTE
# LTU
# LUX
# LVA
# MAC
# MAF
# MAR
# MCO
# MDA
# MDG
# MDV
# MEA
# MEX
# MHL
# MIC
# MKD
# MLI
# MLT
# MMR
# MNA
# MNE
# MNG
# MNP
# MOZ
# ...

# %%
# for code in article_read.Country_Code:
#     print(f"{code} {country_to_continent(code)}")

# %%
# try: 
#   for code in article_read.Country_Code:
#     print(f"{code} {country_to_continent(code)}")
# except:

# %%
# article_read["continent"] = [country_to_continent(x) for x in article_read.Country_Code]

# %%
# try: 
#     for code in article_read.Country_Code:
#     print(f"{code} {country_to_continent(code)}")
# except: 
#     continue

# %%
for code in article_read.Country_Code:
    try: 
        print(f"{code}        {country_to_continent(code)}")
    except:
        print(f"Error: {code}")
        continue
# Out:
# ABW        North America
# Error: AFE
# AFG        Asia
# Error: AFW
# AGO        Africa
# ALB        Europe
# AND        Europe
# Error: ARB
# ARE        Asia
# ARG        South America
# ARM        Asia
# ASM        Oceania
# ATG        North America
# AUS        Oceania
# AUT        Europe
# AZE        Asia
# BDI        Africa
# BEL        Europe
# BEN        Africa
# BFA        Africa
# BGD        Asia
# BGR        Europe
# BHR        Asia
# BHS        North America
# BIH        Europe
# BLR        Europe
# BLZ        North America
# BMU        North America
# BOL        South America
# BRA        South America
# BRB        North America
# BRN        Asia
# BTN        Asia
# BWA        Africa
# CAF        Africa
# CAN        North America
# Error: CEB
# CHE        Europe
# Error: CHI
# CHL        South America
# CHN        Asia
# CIV        Africa
# CMR        Africa
# COD        Africa
# COG        Africa
# COL        South America
# COM        Africa
# CPV        Africa
# ...

# %%
# article_read["continent"] = [country_to_continent(x):
#    for x in article_read.Country_Code
#     try: 
# #         print(f"{code} {country_to_continent(code)}")
#     except:
# #         print(f"Error: {code}")
#         continue]

# %%
# for code in article_read.Country_Code:
#     try: 
#         print(f"{code} {country_to_continent(code)")
#     except: 
#         continue

# %%
continent = []

for code in article_read.Country_Code:
    try: 
        continent.append(country_to_continent(code))
    except: 
        continent.append(code)
        continue 

article_read["continent"] = continent

# %%
article_read["continent"]
# Out:
# 0      North America
# 1                AFE
# 2               Asia
# 3                AFW
# 4             Africa
#            ...
# 261              XKX
# 262             Asia
# 263           Africa
# 264           Africa
# 265           Africa
# Name: continent, Length: 266, dtype: object

# %%
article_read
# Out:
#                     Country_Name Country_Code     Indicator_Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator_Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54208.0      55434.0      56234.0      56699.0
# ...
